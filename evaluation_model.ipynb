# %% [markdown]
# Для проверки модели произведу идентификацию по своему голосу. Для этого необходимо обучить модель на данных, включающих мой голос, а также применить фильтрацию по порогу, который определяет, есть тот или иной голос в рассматрвиаемой базе голосов.
#
# Тестировать буду наилучшую модель, а именно catboost с подобранными параметрами

# %%
from my_funcs import get_dataframe, get_model_and_params, get_feature
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from scipy.spatial.distance import cosine

# %%
df = pd.read_pickle('experiments/crowd_train_all_data_embedded.pkl')

# %%
df_t = get_dataframe(df, 100, 10)
df_t.head()
# Out:
# 354
#                                           audio_path  \
# 0  crowd_train\wavs/cb9733d3521a52dd7a578503dc982...
# 1  crowd_train\wavs/40dddbe3d8c0bcb4fd8b3c933f660...
# 2  crowd_train\wavs/19a6f9ce1902ffb0f45c05f5e621e...
# 3  crowd_train\wavs/d9050a9ec2523b61435ad2a2b4aca...
# 4  crowd_train\wavs/a931c958489a78e12956ebee1e13a...
#
#                           source_id  \
# 0  02d58cb47f02f8884aaa45b0f7dd7714
# 1  02d58cb47f02f8884aaa45b0f7dd7714
# 2  02d58cb47f02f8884aaa45b0f7dd7714
# 3  02d58cb47f02f8884aaa45b0f7dd7714
# 4  02d58cb47f02f8884aaa45b0f7dd7714
#
#                                        audio_feature
# 0  [0.36070194840431213, 0.36269721388816833, 0.3...
# 1  [0.38155198097229004, 0.4070906341075897, 0.44...
# 2  [0.36854031682014465, 0.4035727083683014, 0.44...
# 3  [0.33979716897010803, 0.35216024518013, 0.3810...
# 4  [0.32755956053733826, 0.3753350079059601, 0.39...

# %%
df_me = pd.read_parquet('evaluation/eval_df.pqt')
df_me.head()
# Out:
#            audio_path source_id  \
# 0  maria\Record_0.wav     maria
# 1  maria\Record_1.wav     maria
# 2  maria\Record_2.wav     maria
# 3  maria\Record_3.wav     maria
# 4  maria\Record_4.wav     maria
#
#                                        audio_feature
# 0  [0.22580918669700623, 0.23982486128807068, 0.1...
# 1  [0.2748687267303467, 0.2674121558666229, 0.265...
# 2  [0.21786867082118988, 0.25627416372299194, 0.3...
# 3  [0.3032059073448181, 0.2491905242204666, 0.236...
# 4  [0.17937365174293518, 0.1685197949409485, 0.26...

# %%
eval_df = pd.concat([df_t, df_me]).reset_index(drop=True)

# %%
X = np.vstack(eval_df.audio_feature.to_numpy()).reshape(eval_df.shape[0] , -1)
le = LabelEncoder()
y = pd.DataFrame(le.fit_transform(eval_df.source_id))

X.shape, y.shape
# Out:
# ((3560, 498), (3560, 1))

# %%
le.transform(['me', 'maria']) #добавленные мной классы
# Out:
# array([355, 354])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.5, random_state=42, stratify=y)

# %% [markdown]
# Мои записи голоса, которые не использовались для обучения

# %%
eval_df.iloc[list(set(eval_df[eval_df.source_id == 'me'].index) & set(y_val.index))].sort_index()
# Out:
#            audio_path source_id  \
# 3551  me\Record_1.wav        me
# 3553  me\Record_3.wav        me
# 3555  me\Record_5.wav        me
# 3556  me\Record_6.wav        me
# 3559  me\Record_9.wav        me
#
#                                           audio_feature
# 3551  [0.3570057451725006, 0.391750305891037, 0.2994...
# 3553  [0.333279013633728, 0.3944181501865387, 0.3920...
# 3555  [0.32722488045692444, 0.40390798449516296, 0.2...
# 3556  [0.3516620993614197, 0.39537549018859863, 0.39...
# 3559  [0.4068811237812042, 0.4601544439792633, 0.555...

# %% [markdown]
# Дообучение модели на + 2 новых классах

# %%
import catboost
import json

already_exists = True

if not already_exists:
    pass
    # код, использовавшийся для обучения вынесен в get_evaluation.ipynb
    # из-за громозкости
else:
    model_cb = catboost.CatBoostClassifier()
    model_cb.load_model('cb_model')
    model_name = 'catboost tuned'

    with open(f'cross_validation_scores/{model_name}_threshold.json', 'r') as f:
        d = json.load(f)

# %%
import gradio as gr

def authorize(audio):
    features = get_feature(audio)
    probs = model_cb.predict_proba(features)
    pred_class = le.inverse_transform([np.argmax(probs)])[0]
    max_prob = np.max(probs)

    result = f'Предсказан класс "{pred_class}" с вероятностью {round(max_prob*100, 2)}%'

    c = 0
    train_part_df = eval_df.iloc[
        list(set(eval_df[eval_df.source_id == pred_class].index) - set(y_val.index))
    ]
    for cos_dist_true in train_part_df.audio_feature:
        if cosine(cos_dist_true, features) <= d['tpr@fpr_threshold']:
            c += 1

    if c >= 3:
        result += '\n\nЧеловек присутствует в датасете исходя из косинусного расстояния'
    else:
        result += (
            '\n\nЧеловек НЕ присутствует в датасете исходя из косинусного расстояния'
        )
    if max_prob >= d['threshold']:
        result += '\nЧеловек присутствует в датасете исходя из разделяющего порога вероятности'
    else:
        result += '\nЧеловек НЕ присутствует в датасете исходя из разделяющего порога вероятности'

    return result


with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            audio = gr.Audio(sources=["upload", "microphone"], type="filepath")
        with gr.Column():
            textbox = gr.Textbox()

    button = gr.Button("Отправить")
    button.click(fn=authorize, inputs=[audio], outputs=[textbox])

demo.launch(debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\uvicorn\protocols\http\httptools_impl.py", line 419, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\uvicorn\middleware\proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\gradio\route_utils.py", line 707, in __call__
#     await self.app(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\middleware\exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\routing.py", line 77, in app
#     await response(scope, receive, send)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\responses.py", line 351, in __call__
#     await send(
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\_exception_handler.py", line 50, in sender
#     await send(message)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\_exception_handler.py", line 50, in sender
#     await send(message)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\starlette\middleware\errors.py", line 161, in _send
#     await send(message)
#   File "C:\Users\Никита\AppData\Roaming\Python\Python39\site-packages\uvicorn\protocols\http\httptools_impl.py", line 561, in send
#     raise RuntimeError("Response content shorter than Content-Length")
# RuntimeError: Response content shorter than Content-Length

# %%
import IPython.display as ipd

audio_file = df_t[df_t['source_id'] == '28245faacb3c27e84322dc9547f667ff'].audio_path.iloc[2]
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
