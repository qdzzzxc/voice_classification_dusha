# %%
import catboost
import numpy as np
import optuna
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_pickle('crowd_train_all_data_embedded.pkl')


def get_dataframe(df, min_count, max_count):
    df_temp = df.copy()

    freq = df_temp.source_id.value_counts()
    freq = freq[min_count <= freq]
    df_temp = df_temp[df.source_id.isin(freq.index)]

    df_temp = (
        df_temp.groupby('source_id')
        .apply(lambda x: x.nlargest(max_count, 'duration'))
        .reset_index(drop=True)
        .drop(
            columns=[
                'duration',
                'hash_id',
                'annotator_emo',
                'golden_emo',
                'annotator_id',
                'speaker_text',
                'speaker_emo',
            ]
        )
    )

    df_temp.dropna(inplace=True)

    print(df_temp.source_id.nunique())

    return df_temp


#df_t = get_dataframe(df, 200, 10)
df_t = get_dataframe(df, 100, 10)
# Out:
# 354

# %%
X = np.vstack(df_t.audio_feature.to_numpy()).reshape(df_t.shape[0], -1)
le = LabelEncoder()
y = le.fit_transform(df_t.source_id)

# X = X[:, 36 + 384: 36 + 384 + 60] #mfcc only

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=42, stratify=y
)
X_train.shape, X_test.shape, len(y_train[y_train == 4]), len(y_test[y_test == 4])
# Out:
# ((1770, 498), (1770, 498), 5, 5)

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

def objective(trial, X_train, y_train, X_val, y_val):
    params = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 2, 256),
        'max_depth': trial.suggest_int('max_depth', 2, 16),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2),
        'n_estimators': 1_000,
        'early_stopping_round': 10,
        'device': 'gpu',
    }

    model = lgb.LGBMClassifier(**params)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)])

    preds = model.predict(X_val)
    accuracy = f1_score(y_val, preds, average='weighted')
    return accuracy

def run_optimization(X_train, y_train, X_val, y_val):
    results = []

    study = optuna.create_study(direction='maximize')
    study.optimize(lambda trial: objective(trial, X_train, y_train, X_val, y_val), n_trials=150)

    best_params = study.best_params
    results.append(('best_params', best_params))

    return results

# %%
best_params = run_optimization(X_train, y_train, X_test, y_test)
# Out:
# [I 2024-05-05 16:09:32,068] A new study created in memory with name: no-name-2682aa40-8483-4157-9263-24c7c058c4da
# [I 2024-05-05 16:12:50,846] Trial 0 finished with value: 0.7755262439085969 and parameters: {'num_leaves': 244, 'min_data_in_leaf': 72, 'max_depth': 13, 'lambda_l1': 1.0143511303878232e-07, 'lambda_l2': 4.52661433707551, 'feature_fraction': 0.8775654397072306, 'bagging_fraction': 0.8059415386016378, 'bagging_freq': 3, 'min_child_samples': 75, 'learning_rate': 0.11401396667236176}. Best is trial 0 with value: 0.7755262439085969.
# [I 2024-05-05 16:14:48,445] Trial 1 finished with value: 0.8245665010370892 and parameters: {'num_leaves': 140, 'min_data_in_leaf': 200, 'max_depth': 15, 'lambda_l1': 2.419139151240461e-08, 'lambda_l2': 0.7753932753464238, 'feature_fraction': 0.733935813646829, 'bagging_fraction': 0.8882973688603936, 'bagging_freq': 2, 'min_child_samples': 99, 'learning_rate': 0.1691946730261765}. Best is trial 1 with value: 0.8245665010370892.
# [I 2024-05-05 16:16:21,521] Trial 2 finished with value: 0.8437122245945776 and parameters: {'num_leaves': 75, 'min_data_in_leaf': 111, 'max_depth': 12, 'lambda_l1': 8.078743353332975e-08, 'lambda_l2': 0.19981265336945908, 'feature_fraction': 0.43448817160720077, 'bagging_fraction': 0.48778191952430017, 'bagging_freq': 2, 'min_child_samples': 38, 'learning_rate': 0.044515879749560755}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:16:37,113] Trial 3 finished with value: 0.729838734250499 and parameters: {'num_leaves': 221, 'min_data_in_leaf': 25, 'max_depth': 4, 'lambda_l1': 0.0006119466826170006, 'lambda_l2': 2.8034918265737706e-05, 'feature_fraction': 0.7207743456384406, 'bagging_fraction': 0.865765551794328, 'bagging_freq': 5, 'min_child_samples': 98, 'learning_rate': 0.1173112235364613}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:17:34,353] Trial 4 finished with value: 0.8340305119716885 and parameters: {'num_leaves': 52, 'min_data_in_leaf': 205, 'max_depth': 10, 'lambda_l1': 1.0225296334689171e-05, 'lambda_l2': 0.00024469538595044984, 'feature_fraction': 0.8218622601675085, 'bagging_fraction': 0.8775576114707142, 'bagging_freq': 4, 'min_child_samples': 50, 'learning_rate': 0.02300962228769628}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:18:04,423] Trial 5 finished with value: 0.7380588365882483 and parameters: {'num_leaves': 237, 'min_data_in_leaf': 39, 'max_depth': 12, 'lambda_l1': 0.008289884694075933, 'lambda_l2': 1.7947614102664998e-07, 'feature_fraction': 0.7712435725521932, 'bagging_fraction': 0.9364866144615954, 'bagging_freq': 1, 'min_child_samples': 73, 'learning_rate': 0.13523026783944284}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:20:00,102] Trial 6 finished with value: 0.8306696571402453 and parameters: {'num_leaves': 165, 'min_data_in_leaf': 141, 'max_depth': 9, 'lambda_l1': 0.05161833195520006, 'lambda_l2': 2.5842761601529394, 'feature_fraction': 0.5203668439906066, 'bagging_fraction': 0.7377681058827636, 'bagging_freq': 3, 'min_child_samples': 43, 'learning_rate': 0.12066637031720483}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:20:24,728] Trial 7 finished with value: 0.7807061130590544 and parameters: {'num_leaves': 45, 'min_data_in_leaf': 49, 'max_depth': 2, 'lambda_l1': 0.0008607511617394164, 'lambda_l2': 1.6011411241483053e-05, 'feature_fraction': 0.4437304114729078, 'bagging_fraction': 0.7539609237379632, 'bagging_freq': 6, 'min_child_samples': 37, 'learning_rate': 0.07020662054330742}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:21:07,105] Trial 8 finished with value: 0.7728125360478302 and parameters: {'num_leaves': 222, 'min_data_in_leaf': 80, 'max_depth': 3, 'lambda_l1': 9.997537511552479e-08, 'lambda_l2': 0.020275827789547833, 'feature_fraction': 0.7205752672629876, 'bagging_fraction': 0.6900233472799064, 'bagging_freq': 6, 'min_child_samples': 14, 'learning_rate': 0.08543032002210217}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:21:55,960] Trial 9 finished with value: 0.7861649244002186 and parameters: {'num_leaves': 129, 'min_data_in_leaf': 148, 'max_depth': 9, 'lambda_l1': 0.0018133867653803626, 'lambda_l2': 0.045388009198019094, 'feature_fraction': 0.45449494031019594, 'bagging_fraction': 0.9686599346917613, 'bagging_freq': 3, 'min_child_samples': 94, 'learning_rate': 0.1740684480764934}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:21:56,237] Trial 10 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 96, 'min_data_in_leaf': 236, 'max_depth': 6, 'lambda_l1': 6.696349559126246, 'lambda_l2': 0.020701573550355557, 'feature_fraction': 0.5661934566979101, 'bagging_fraction': 0.47084837149994396, 'bagging_freq': 1, 'min_child_samples': 6, 'learning_rate': 0.02385636917606794}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:21:56,486] Trial 11 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 23, 'min_data_in_leaf': 182, 'max_depth': 11, 'lambda_l1': 7.921025502624046e-06, 'lambda_l2': 0.0001161227381975357, 'feature_fraction': 0.9748302081822986, 'bagging_fraction': 0.40102875326042875, 'bagging_freq': 4, 'min_child_samples': 32, 'learning_rate': 0.005136677301431147}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:21:56,771] Trial 12 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 68, 'min_data_in_leaf': 256, 'max_depth': 7, 'lambda_l1': 2.631013406369994e-06, 'lambda_l2': 0.0013085678921470755, 'feature_fraction': 0.8444203745911714, 'bagging_fraction': 0.5925089108991729, 'bagging_freq': 7, 'min_child_samples': 58, 'learning_rate': 0.04722583645639237}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:22:38,024] Trial 13 finished with value: 0.8220774323715501 and parameters: {'num_leaves': 5, 'min_data_in_leaf': 104, 'max_depth': 16, 'lambda_l1': 7.2335778847256916e-06, 'lambda_l2': 8.867682585639344e-07, 'feature_fraction': 0.6009555689904473, 'bagging_fraction': 0.6135596577762955, 'bagging_freq': 4, 'min_child_samples': 57, 'learning_rate': 0.04005992243410263}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:22:38,384] Trial 14 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 76, 'min_data_in_leaf': 177, 'max_depth': 11, 'lambda_l1': 8.064311535327602e-07, 'lambda_l2': 0.0007559300316671213, 'feature_fraction': 0.6396045805754721, 'bagging_fraction': 0.5163635550693458, 'bagging_freq': 2, 'min_child_samples': 21, 'learning_rate': 0.06107830116163877}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:25:07,572] Trial 15 finished with value: 0.8075507825507826 and parameters: {'num_leaves': 109, 'min_data_in_leaf': 105, 'max_depth': 14, 'lambda_l1': 4.421765089369223e-05, 'lambda_l2': 0.16136780941286163, 'feature_fraction': 0.836692465952713, 'bagging_fraction': 0.6333289857777779, 'bagging_freq': 5, 'min_child_samples': 48, 'learning_rate': 0.010406599227523863}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:25:07,865] Trial 16 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 48, 'min_data_in_leaf': 222, 'max_depth': 10, 'lambda_l1': 1.259662604765882e-08, 'lambda_l2': 1.7906765516206062e-08, 'feature_fraction': 0.9851412898576218, 'bagging_fraction': 0.8298041740214496, 'bagging_freq': 2, 'min_child_samples': 30, 'learning_rate': 0.08785175157623074}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:25:49,920] Trial 17 finished with value: 0.824580267227326 and parameters: {'num_leaves': 163, 'min_data_in_leaf': 122, 'max_depth': 7, 'lambda_l1': 4.8483681322834945e-05, 'lambda_l2': 0.0033454767755840714, 'feature_fraction': 0.6501436645346297, 'bagging_fraction': 0.5337236174678175, 'bagging_freq': 5, 'min_child_samples': 66, 'learning_rate': 0.03414414875108511}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:25:50,202] Trial 18 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 81, 'min_data_in_leaf': 165, 'max_depth': 13, 'lambda_l1': 2.2225278351526727e-07, 'lambda_l2': 4.103390245449883e-06, 'feature_fraction': 0.9197794895729219, 'bagging_fraction': 0.41062162421552506, 'bagging_freq': 3, 'min_child_samples': 26, 'learning_rate': 0.06030101382706857}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:26:50,374] Trial 19 finished with value: 0.8063773916715093 and parameters: {'num_leaves': 41, 'min_data_in_leaf': 200, 'max_depth': 8, 'lambda_l1': 6.406804165698232e-05, 'lambda_l2': 0.00014235378279579684, 'feature_fraction': 0.482788214480243, 'bagging_fraction': 0.9928440115806052, 'bagging_freq': 1, 'min_child_samples': 41, 'learning_rate': 0.0246894943655439}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:26:52,530] Trial 20 finished with value: 0.18564312650999956 and parameters: {'num_leaves': 5, 'min_data_in_leaf': 6, 'max_depth': 11, 'lambda_l1': 0.18220400953710042, 'lambda_l2': 0.004346458551520497, 'feature_fraction': 0.7970106659093061, 'bagging_fraction': 0.6704637002419966, 'bagging_freq': 4, 'min_child_samples': 49, 'learning_rate': 0.1998209716214531}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:28:44,989] Trial 21 finished with value: 0.8395921072391661 and parameters: {'num_leaves': 180, 'min_data_in_leaf': 140, 'max_depth': 9, 'lambda_l1': 0.024418912843520685, 'lambda_l2': 9.589729936586549, 'feature_fraction': 0.40283724659410336, 'bagging_fraction': 0.7459958422872377, 'bagging_freq': 3, 'min_child_samples': 42, 'learning_rate': 0.13428790082976777}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:29:30,953] Trial 22 finished with value: 0.7899091649091649 and parameters: {'num_leaves': 194, 'min_data_in_leaf': 108, 'max_depth': 5, 'lambda_l1': 0.49172042931903165, 'lambda_l2': 0.40791987141259295, 'feature_fraction': 0.42413373096310014, 'bagging_fraction': 0.786726236286956, 'bagging_freq': 2, 'min_child_samples': 62, 'learning_rate': 0.14641605136595665}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:31:33,483] Trial 23 finished with value: 0.8258960538372302 and parameters: {'num_leaves': 179, 'min_data_in_leaf': 157, 'max_depth': 10, 'lambda_l1': 0.016140296318444294, 'lambda_l2': 1.6700561244553145, 'feature_fraction': 0.5173517035123559, 'bagging_fraction': 0.8872039619389761, 'bagging_freq': 4, 'min_child_samples': 48, 'learning_rate': 0.09197361191387643}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:33:46,130] Trial 24 finished with value: 0.8075853340559224 and parameters: {'num_leaves': 116, 'min_data_in_leaf': 82, 'max_depth': 8, 'lambda_l1': 8.913104932829128e-07, 'lambda_l2': 5.6929052926644985, 'feature_fraction': 0.400786440733626, 'bagging_fraction': 0.7338573588939792, 'bagging_freq': 3, 'min_child_samples': 37, 'learning_rate': 0.14123906130634162}. Best is trial 2 with value: 0.8437122245945776.
# [I 2024-05-05 16:34:45,501] Trial 25 finished with value: 0.8530922236804589 and parameters: {'num_leaves': 62, 'min_data_in_leaf': 134, 'max_depth': 13, 'lambda_l1': 2.0874471021265584, 'lambda_l2': 0.12414270418404381, 'feature_fraction': 0.5443170651619815, 'bagging_fraction': 0.5572081912042213, 'bagging_freq': 2, 'min_child_samples': 22, 'learning_rate': 0.07375650805001206}. Best is trial 25 with value: 0.8530922236804589.
# [I 2024-05-05 16:35:48,995] Trial 26 finished with value: 0.8593778226131167 and parameters: {'num_leaves': 138, 'min_data_in_leaf': 128, 'max_depth': 13, 'lambda_l1': 2.015469881374128, 'lambda_l2': 0.24441325297192767, 'feature_fraction': 0.5170111004476576, 'bagging_fraction': 0.555358874406201, 'bagging_freq': 2, 'min_child_samples': 18, 'learning_rate': 0.06917837564200602}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:35:49,716] Trial 27 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 143, 'min_data_in_leaf': 124, 'max_depth': 14, 'lambda_l1': 3.9943632576562904, 'lambda_l2': 0.09827082093961725, 'feature_fraction': 0.5533794598998747, 'bagging_fraction': 0.5632062938620642, 'bagging_freq': 2, 'min_child_samples': 15, 'learning_rate': 0.07126026074280864}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:36:56,441] Trial 28 finished with value: 0.8407168811580575 and parameters: {'num_leaves': 95, 'min_data_in_leaf': 95, 'max_depth': 16, 'lambda_l1': 1.7628394942505836, 'lambda_l2': 0.3087515243679157, 'feature_fraction': 0.49113757833906857, 'bagging_fraction': 0.4599889158474364, 'bagging_freq': 1, 'min_child_samples': 5, 'learning_rate': 0.055377310659689385}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:38:11,454] Trial 29 finished with value: 0.7393302775655717 and parameters: {'num_leaves': 62, 'min_data_in_leaf': 57, 'max_depth': 13, 'lambda_l1': 0.5062021774189837, 'lambda_l2': 0.00628652090347318, 'feature_fraction': 0.6516872742808761, 'bagging_fraction': 0.4940392360493023, 'bagging_freq': 2, 'min_child_samples': 21, 'learning_rate': 0.10279320824868778}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:38:53,878] Trial 30 finished with value: 0.832802001919649 and parameters: {'num_leaves': 88, 'min_data_in_leaf': 125, 'max_depth': 12, 'lambda_l1': 0.00454422579176441, 'lambda_l2': 0.03465021879754889, 'feature_fraction': 0.595948543948804, 'bagging_fraction': 0.5651658457235231, 'bagging_freq': 1, 'min_child_samples': 15, 'learning_rate': 0.07960897879269811}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:40:09,662] Trial 31 finished with value: 0.7902938292644175 and parameters: {'num_leaves': 105, 'min_data_in_leaf': 70, 'max_depth': 16, 'lambda_l1': 1.7562660110746802, 'lambda_l2': 0.32960606282103155, 'feature_fraction': 0.48829133018614307, 'bagging_fraction': 0.45217534066061305, 'bagging_freq': 1, 'min_child_samples': 5, 'learning_rate': 0.05214400401902924}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:41:17,290] Trial 32 finished with value: 0.8442745163333399 and parameters: {'num_leaves': 123, 'min_data_in_leaf': 96, 'max_depth': 15, 'lambda_l1': 1.3283133073218962, 'lambda_l2': 1.1326869041975864, 'feature_fraction': 0.47547230254492084, 'bagging_fraction': 0.4519365440028025, 'bagging_freq': 2, 'min_child_samples': 11, 'learning_rate': 0.1001308537273691}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:42:48,422] Trial 33 finished with value: 0.819826905121023 and parameters: {'num_leaves': 142, 'min_data_in_leaf': 94, 'max_depth': 14, 'lambda_l1': 0.15970590847001417, 'lambda_l2': 1.1417892823352198, 'feature_fraction': 0.5387882295297244, 'bagging_fraction': 0.5413193527683338, 'bagging_freq': 2, 'min_child_samples': 24, 'learning_rate': 0.10403315011474869}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:42:48,940] Trial 34 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 130, 'min_data_in_leaf': 117, 'max_depth': 15, 'lambda_l1': 9.3455841015643, 'lambda_l2': 0.9998141302936111, 'feature_fraction': 0.46154411977781123, 'bagging_fraction': 0.43368288620880074, 'bagging_freq': 2, 'min_child_samples': 14, 'learning_rate': 0.07433234475114406}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:42:49,193] Trial 35 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 30, 'min_data_in_leaf': 168, 'max_depth': 15, 'lambda_l1': 1.1385459746023197, 'lambda_l2': 0.12583818936562988, 'feature_fraction': 0.5859514161960737, 'bagging_fraction': 0.5026325158321847, 'bagging_freq': 3, 'min_child_samples': 31, 'learning_rate': 0.11411158287494486}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:43:26,566] Trial 36 finished with value: 0.8180096047743107 and parameters: {'num_leaves': 118, 'min_data_in_leaf': 140, 'max_depth': 12, 'lambda_l1': 0.08804443951525717, 'lambda_l2': 0.008071539112831047, 'feature_fraction': 0.5140129241975583, 'bagging_fraction': 0.6486491247860006, 'bagging_freq': 2, 'min_child_samples': 11, 'learning_rate': 0.0952877242498053}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:45:56,768] Trial 37 finished with value: 0.8170763060468943 and parameters: {'num_leaves': 68, 'min_data_in_leaf': 84, 'max_depth': 13, 'lambda_l1': 0.00019594277819321676, 'lambda_l2': 2.2151370428347477, 'feature_fraction': 0.43699515009265005, 'bagging_fraction': 0.5835882294157946, 'bagging_freq': 1, 'min_child_samples': 21, 'learning_rate': 0.04008472409668237}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:47:35,022] Trial 38 finished with value: 0.7010158142511085 and parameters: {'num_leaves': 162, 'min_data_in_leaf': 33, 'max_depth': 14, 'lambda_l1': 0.4537424718021951, 'lambda_l2': 0.049650769583673364, 'feature_fraction': 0.6897167369881421, 'bagging_fraction': 0.48581735283434124, 'bagging_freq': 3, 'min_child_samples': 27, 'learning_rate': 0.12504763074690114}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:49:37,074] Trial 39 finished with value: 0.7984808764220529 and parameters: {'num_leaves': 150, 'min_data_in_leaf': 64, 'max_depth': 13, 'lambda_l1': 0.04321458590152895, 'lambda_l2': 0.5267756198846261, 'feature_fraction': 0.6182071386484118, 'bagging_fraction': 0.5407136754399675, 'bagging_freq': 2, 'min_child_samples': 35, 'learning_rate': 0.06224508002272153}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:49:37,412] Trial 40 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 199, 'min_data_in_leaf': 150, 'max_depth': 15, 'lambda_l1': 2.587429964433396, 'lambda_l2': 3.2292324779811947, 'feature_fraction': 0.4731167219902577, 'bagging_fraction': 0.4408331749692906, 'bagging_freq': 3, 'min_child_samples': 90, 'learning_rate': 0.08218643523868127}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:50:49,023] Trial 41 finished with value: 0.8450959715665599 and parameters: {'num_leaves': 98, 'min_data_in_leaf': 93, 'max_depth': 16, 'lambda_l1': 1.0046522957519846, 'lambda_l2': 0.21468497602998884, 'feature_fraction': 0.4953474188451072, 'bagging_fraction': 0.4664328698875543, 'bagging_freq': 1, 'min_child_samples': 9, 'learning_rate': 0.05227674327629592}. Best is trial 26 with value: 0.8593778226131167.
# [I 2024-05-05 16:51:09,456] Trial 42 finished with value: 0.8635112164523929 and parameters: {'num_leaves': 125, 'min_data_in_leaf': 133, 'max_depth': 16, 'lambda_l1': 0.6701088054904991, 'lambda_l2': 0.10799525866903388, 'feature_fraction': 0.5197477617579179, 'bagging_fraction': 0.5172259870127421, 'bagging_freq': 1, 'min_child_samples': 10, 'learning_rate': 0.06973037352729819}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:51:11,401] Trial 43 finished with value: 0.36823507387024645 and parameters: {'num_leaves': 124, 'min_data_in_leaf': 134, 'max_depth': 16, 'lambda_l1': 0.6997274242309839, 'lambda_l2': 0.016061301431866615, 'feature_fraction': 0.538141651621896, 'bagging_fraction': 0.5151706834267975, 'bagging_freq': 1, 'min_child_samples': 9, 'learning_rate': 0.06718522027164166}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:52:21,421] Trial 44 finished with value: 0.8072886264062735 and parameters: {'num_leaves': 101, 'min_data_in_leaf': 94, 'max_depth': 15, 'lambda_l1': 0.16183519181052966, 'lambda_l2': 0.05701234332543863, 'feature_fraction': 0.5736054044485884, 'bagging_fraction': 0.4733276720673283, 'bagging_freq': 1, 'min_child_samples': 18, 'learning_rate': 0.09828965427329042}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:52:21,746] Trial 45 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 153, 'min_data_in_leaf': 187, 'max_depth': 15, 'lambda_l1': 4.988616624150943, 'lambda_l2': 0.6818810856699844, 'feature_fraction': 0.5324500650439927, 'bagging_fraction': 0.6071055921505044, 'bagging_freq': 1, 'min_child_samples': 10, 'learning_rate': 0.0756740082076631}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:52:22,263] Trial 46 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 133, 'min_data_in_leaf': 112, 'max_depth': 16, 'lambda_l1': 9.97670122310929, 'lambda_l2': 0.1714714015306862, 'feature_fraction': 0.5037285120702578, 'bagging_fraction': 0.43341499101702385, 'bagging_freq': 1, 'min_child_samples': 18, 'learning_rate': 0.10823360990386595}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:52:23,499] Trial 47 finished with value: 0.21956087840120428 and parameters: {'num_leaves': 86, 'min_data_in_leaf': 151, 'max_depth': 14, 'lambda_l1': 0.26434357144601794, 'lambda_l2': 0.0015061575793443832, 'feature_fraction': 0.6812143475094175, 'bagging_fraction': 0.566017725524482, 'bagging_freq': 2, 'min_child_samples': 10, 'learning_rate': 0.04663370386039033}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:53:32,139] Trial 48 finished with value: 0.8246664011369894 and parameters: {'num_leaves': 113, 'min_data_in_leaf': 99, 'max_depth': 15, 'lambda_l1': 1.2789955905620012, 'lambda_l2': 0.02015029507473411, 'feature_fraction': 0.5592748892831474, 'bagging_fraction': 0.5232110986472933, 'bagging_freq': 1, 'min_child_samples': 83, 'learning_rate': 0.08494718664074878}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:53:32,489] Trial 49 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 136, 'min_data_in_leaf': 136, 'max_depth': 16, 'lambda_l1': 0.060943063543953735, 'lambda_l2': 9.44964552038441, 'feature_fraction': 0.4618354811157124, 'bagging_fraction': 0.405828301937736, 'bagging_freq': 2, 'min_child_samples': 18, 'learning_rate': 0.03402041086380716}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:55:55,664] Trial 50 finished with value: 0.7327666342372224 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 48, 'max_depth': 12, 'lambda_l1': 0.00516847300066491, 'lambda_l2': 0.11574336635797407, 'feature_fraction': 0.6209992452254495, 'bagging_fraction': 0.6241262907965821, 'bagging_freq': 7, 'min_child_samples': 8, 'learning_rate': 0.05485523272762446}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:55:56,250] Trial 51 finished with value: 0.006997844074433539 and parameters: {'num_leaves': 72, 'min_data_in_leaf': 129, 'max_depth': 13, 'lambda_l1': 3.4293280457429667, 'lambda_l2': 0.3827830661505429, 'feature_fraction': 0.42989825539599164, 'bagging_fraction': 0.4827553161371686, 'bagging_freq': 2, 'min_child_samples': 24, 'learning_rate': 0.06581900506049367}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:57:45,733] Trial 52 finished with value: 0.8299519108342638 and parameters: {'num_leaves': 95, 'min_data_in_leaf': 82, 'max_depth': 12, 'lambda_l1': 0.9288895947068595, 'lambda_l2': 3.1598524159525154, 'feature_fraction': 0.44813815569038823, 'bagging_fraction': 0.5055228193849012, 'bagging_freq': 2, 'min_child_samples': 12, 'learning_rate': 0.03994347454103754}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 16:59:39,358] Trial 53 finished with value: 0.8312413621237151 and parameters: {'num_leaves': 121, 'min_data_in_leaf': 112, 'max_depth': 14, 'lambda_l1': 1.4492738286843945e-07, 'lambda_l2': 0.18301681234306233, 'feature_fraction': 0.5034676030269808, 'bagging_fraction': 0.5464128800235345, 'bagging_freq': 1, 'min_child_samples': 28, 'learning_rate': 0.04584033103514049}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 17:01:24,336] Trial 54 finished with value: 0.8458673679261914 and parameters: {'num_leaves': 35, 'min_data_in_leaf': 121, 'max_depth': 11, 'lambda_l1': 0.0010685023727354513, 'lambda_l2': 0.06808637426122739, 'feature_fraction': 0.42762920376573804, 'bagging_fraction': 0.5901318056940807, 'bagging_freq': 3, 'min_child_samples': 16, 'learning_rate': 0.01719840867314497}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 17:01:24,648] Trial 55 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 32, 'min_data_in_leaf': 164, 'max_depth': 11, 'lambda_l1': 0.331078650083746, 'lambda_l2': 0.012298972809928005, 'feature_fraction': 0.468026569465299, 'bagging_fraction': 0.59771995000401, 'bagging_freq': 3, 'min_child_samples': 17, 'learning_rate': 0.015954474583267403}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 17:03:39,371] Trial 56 finished with value: 0.8195860784096077 and parameters: {'num_leaves': 24, 'min_data_in_leaf': 123, 'max_depth': 15, 'lambda_l1': 0.0007712293659392776, 'lambda_l2': 0.05749197907122476, 'feature_fraction': 0.7664228995465382, 'bagging_fraction': 0.6563629777686016, 'bagging_freq': 3, 'min_child_samples': 23, 'learning_rate': 0.030516123974538466}. Best is trial 42 with value: 0.8635112164523929.
# [I 2024-05-05 17:04:23,756] Trial 57 finished with value: 0.8737578597872716 and parameters: {'num_leaves': 16, 'min_data_in_leaf': 147, 'max_depth': 11, 'lambda_l1': 0.024084194758356776, 'lambda_l2': 0.9095572498285026, 'feature_fraction': 0.41779109546476983, 'bagging_fraction': 0.577883508320407, 'bagging_freq': 2, 'min_child_samples': 12, 'learning_rate': 0.014343981229108849}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:05:36,125] Trial 58 finished with value: 0.8405010566775274 and parameters: {'num_leaves': 12, 'min_data_in_leaf': 145, 'max_depth': 11, 'lambda_l1': 0.0017643705372626319, 'lambda_l2': 0.0024226533899859683, 'feature_fraction': 0.4143775490548509, 'bagging_fraction': 0.688239782899232, 'bagging_freq': 6, 'min_child_samples': 14, 'learning_rate': 0.019768857471428383}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:05:36,407] Trial 59 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 16, 'min_data_in_leaf': 174, 'max_depth': 10, 'lambda_l1': 0.00027763011916451014, 'lambda_l2': 0.0006706861616928656, 'feature_fraction': 0.4433721872601524, 'bagging_fraction': 0.5894071004550614, 'bagging_freq': 2, 'min_child_samples': 33, 'learning_rate': 0.01061247922880507}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:06:22,828] Trial 60 finished with value: 0.8434648412589588 and parameters: {'num_leaves': 40, 'min_data_in_leaf': 135, 'max_depth': 10, 'lambda_l1': 0.017143144918338234, 'lambda_l2': 2.6056799763416726e-05, 'feature_fraction': 0.5254966486144822, 'bagging_fraction': 0.5707327661440907, 'bagging_freq': 3, 'min_child_samples': 7, 'learning_rate': 0.026285416226669467}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:06:23,105] Trial 61 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 158, 'max_depth': 9, 'lambda_l1': 2.413084578175432, 'lambda_l2': 1.1845706764224961, 'feature_fraction': 0.4876529448265968, 'bagging_fraction': 0.5489135573830788, 'bagging_freq': 2, 'min_child_samples': 12, 'learning_rate': 0.006755096815812827}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:07:30,346] Trial 62 finished with value: 0.8670600097070685 and parameters: {'num_leaves': 35, 'min_data_in_leaf': 115, 'max_depth': 13, 'lambda_l1': 0.14007297122065412, 'lambda_l2': 0.0802474238455414, 'feature_fraction': 0.4522832844086595, 'bagging_fraction': 0.5219846232469249, 'bagging_freq': 2, 'min_child_samples': 19, 'learning_rate': 0.053728335285087796}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:08:16,551] Trial 63 finished with value: 0.828378375437199 and parameters: {'num_leaves': 35, 'min_data_in_leaf': 120, 'max_depth': 11, 'lambda_l1': 0.03219400158409112, 'lambda_l2': 0.04431209053488582, 'feature_fraction': 0.41918697088530804, 'bagging_fraction': 0.5228589712700015, 'bagging_freq': 1, 'min_child_samples': 20, 'learning_rate': 0.05241347123366785}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:08:58,171] Trial 64 finished with value: 0.7757266698443169 and parameters: {'num_leaves': 47, 'min_data_in_leaf': 104, 'max_depth': 12, 'lambda_l1': 0.09656048675216837, 'lambda_l2': 0.10479641788621064, 'feature_fraction': 0.4042869519329005, 'bagging_fraction': 0.9175198913423751, 'bagging_freq': 4, 'min_child_samples': 15, 'learning_rate': 0.05948836554612395}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:10:38,286] Trial 65 finished with value: 0.8290758261346496 and parameters: {'num_leaves': 18, 'min_data_in_leaf': 130, 'max_depth': 13, 'lambda_l1': 0.00853896021089536, 'lambda_l2': 0.23259950112821548, 'feature_fraction': 0.44793807034450206, 'bagging_fraction': 0.6242746332436987, 'bagging_freq': 3, 'min_child_samples': 28, 'learning_rate': 0.08980162658565026}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:12:27,481] Trial 66 finished with value: 0.8343420740479564 and parameters: {'num_leaves': 11, 'min_data_in_leaf': 115, 'max_depth': 2, 'lambda_l1': 0.0019453336531890545, 'lambda_l2': 0.027897723341959075, 'feature_fraction': 0.5093060854687597, 'bagging_fraction': 0.5814441460150437, 'bagging_freq': 2, 'min_child_samples': 5, 'learning_rate': 0.015763229525713088}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:13:46,417] Trial 67 finished with value: 0.8489025952261247 and parameters: {'num_leaves': 25, 'min_data_in_leaf': 156, 'max_depth': 12, 'lambda_l1': 0.28417187300010077, 'lambda_l2': 0.5051642938151518, 'feature_fraction': 0.5468770307920264, 'bagging_fraction': 0.7092354918586886, 'bagging_freq': 1, 'min_child_samples': 24, 'learning_rate': 0.0380748914950591}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:14:54,388] Trial 68 finished with value: 0.8277825116060411 and parameters: {'num_leaves': 24, 'min_data_in_leaf': 152, 'max_depth': 12, 'lambda_l1': 0.14580290090557443, 'lambda_l2': 1.3162139174622093e-08, 'feature_fraction': 0.5561383587025278, 'bagging_fraction': 0.7870096547928664, 'bagging_freq': 2, 'min_child_samples': 25, 'learning_rate': 0.031515640320791787}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:14:54,873] Trial 69 finished with value: 0.01629824133528189 and parameters: {'num_leaves': 2, 'min_data_in_leaf': 189, 'max_depth': 10, 'lambda_l1': 0.08785095298270446, 'lambda_l2': 0.6834344249701978, 'feature_fraction': 0.5794446380315527, 'bagging_fraction': 0.7135430359803057, 'bagging_freq': 1, 'min_child_samples': 39, 'learning_rate': 0.04021567069037202}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:14:55,143] Trial 70 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 40, 'min_data_in_leaf': 212, 'max_depth': 8, 'lambda_l1': 0.2781247943498885, 'lambda_l2': 5.682639999023683, 'feature_fraction': 0.5462136748888945, 'bagging_fraction': 0.6808844161559704, 'bagging_freq': 3, 'min_child_samples': 22, 'learning_rate': 0.025030165525881765}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:16:04,159] Trial 71 finished with value: 0.8589862751627458 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 141, 'max_depth': 13, 'lambda_l1': 0.6828689824518115, 'lambda_l2': 0.07526950695010602, 'feature_fraction': 0.4930658595010356, 'bagging_fraction': 0.7093156200354879, 'bagging_freq': 1, 'min_child_samples': 17, 'learning_rate': 0.05065702058613826}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:17:07,948] Trial 72 finished with value: 0.8454079145255616 and parameters: {'num_leaves': 52, 'min_data_in_leaf': 143, 'max_depth': 13, 'lambda_l1': 0.583316573563224, 'lambda_l2': 0.07108136804689308, 'feature_fraction': 0.4271964862730487, 'bagging_fraction': 0.7098090565845654, 'bagging_freq': 1, 'min_child_samples': 19, 'learning_rate': 0.06989110797264114}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:17:08,624] Trial 73 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 30, 'min_data_in_leaf': 159, 'max_depth': 11, 'lambda_l1': 4.951840022221441, 'lambda_l2': 0.3869618495410487, 'feature_fraction': 0.47529831617714086, 'bagging_fraction': 0.7255201964769303, 'bagging_freq': 1, 'min_child_samples': 17, 'learning_rate': 0.03779024594735451}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:17:09,133] Trial 74 finished with value: 0.014440928576670401 and parameters: {'num_leaves': 65, 'min_data_in_leaf': 172, 'max_depth': 13, 'lambda_l1': 1.8883171378964258e-05, 'lambda_l2': 0.009589529567773116, 'feature_fraction': 0.5191223205223756, 'bagging_fraction': 0.6427680690139629, 'bagging_freq': 2, 'min_child_samples': 15, 'learning_rate': 0.07750649366969889}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:17:44,695] Trial 75 finished with value: 0.8253361018066901 and parameters: {'num_leaves': 20, 'min_data_in_leaf': 143, 'max_depth': 12, 'lambda_l1': 0.2784623764145923, 'lambda_l2': 2.0849516293579305e-07, 'feature_fraction': 0.4546605950934616, 'bagging_fraction': 0.782594315092343, 'bagging_freq': 2, 'min_child_samples': 13, 'learning_rate': 0.060697921542771524}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:19:57,467] Trial 76 finished with value: 0.8239001466942643 and parameters: {'num_leaves': 58, 'min_data_in_leaf': 129, 'max_depth': 14, 'lambda_l1': 0.00015359908956540834, 'lambda_l2': 1.7471646835128467, 'feature_fraction': 0.610290742022684, 'bagging_fraction': 0.7615537038552185, 'bagging_freq': 1, 'min_child_samples': 53, 'learning_rate': 0.01941890708700278}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:20:32,008] Trial 77 finished with value: 0.8414953510541745 and parameters: {'num_leaves': 46, 'min_data_in_leaf': 162, 'max_depth': 11, 'lambda_l1': 0.011987616926425394, 'lambda_l2': 0.029727907635738075, 'feature_fraction': 0.48681395932119914, 'bagging_fraction': 0.6681706597926034, 'bagging_freq': 4, 'min_child_samples': 22, 'learning_rate': 0.04817786888851368}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:20:32,320] Trial 78 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 78, 'min_data_in_leaf': 180, 'max_depth': 12, 'lambda_l1': 2.0797049859731698, 'lambda_l2': 0.08429490222052671, 'feature_fraction': 0.9157688583366681, 'bagging_fraction': 0.55334384914387, 'bagging_freq': 1, 'min_child_samples': 67, 'learning_rate': 0.06402306802560237}. Best is trial 57 with value: 0.8737578597872716.
# [I 2024-05-05 17:21:25,727] Trial 79 finished with value: 0.874839158662688 and parameters: {'num_leaves': 9, 'min_data_in_leaf': 151, 'max_depth': 3, 'lambda_l1': 0.05156122427614393, 'lambda_l2': 0.917067067731611, 'feature_fraction': 0.5345089078095386, 'bagging_fraction': 0.6022498606851232, 'bagging_freq': 2, 'min_child_samples': 30, 'learning_rate': 0.011302934154635014}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:23:23,176] Trial 80 finished with value: 0.8346477596477596 and parameters: {'num_leaves': 9, 'min_data_in_leaf': 155, 'max_depth': 3, 'lambda_l1': 0.03913849534208974, 'lambda_l2': 0.6511734838341944, 'feature_fraction': 0.5892399982221911, 'bagging_fraction': 0.8299472596643996, 'bagging_freq': 2, 'min_child_samples': 30, 'learning_rate': 0.027583607681755162}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:24:40,032] Trial 81 finished with value: 0.8647589338765809 and parameters: {'num_leaves': 247, 'min_data_in_leaf': 137, 'max_depth': 5, 'lambda_l1': 0.6779008524958093, 'lambda_l2': 0.23008639693899915, 'feature_fraction': 0.5228826613467669, 'bagging_fraction': 0.611858935933444, 'bagging_freq': 2, 'min_child_samples': 24, 'learning_rate': 0.013456994592401005}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:25:53,419] Trial 82 finished with value: 0.8593088284264754 and parameters: {'num_leaves': 255, 'min_data_in_leaf': 138, 'max_depth': 5, 'lambda_l1': 0.6898153946625678, 'lambda_l2': 0.3475906484128947, 'feature_fraction': 0.5309087330375625, 'bagging_fraction': 0.6110963039519967, 'bagging_freq': 2, 'min_child_samples': 44, 'learning_rate': 0.010394922073058657}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:26:59,184] Trial 83 finished with value: 0.8304010259892612 and parameters: {'num_leaves': 252, 'min_data_in_leaf': 140, 'max_depth': 4, 'lambda_l1': 0.7299262578444367, 'lambda_l2': 2.0226387160519965, 'feature_fraction': 0.5675192070138887, 'bagging_fraction': 0.6076378156409976, 'bagging_freq': 2, 'min_child_samples': 45, 'learning_rate': 0.011427248994770928}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:28:04,320] Trial 84 finished with value: 0.714237314972609 and parameters: {'num_leaves': 219, 'min_data_in_leaf': 147, 'max_depth': 6, 'lambda_l1': 1.5695340741448909, 'lambda_l2': 0.2447759525184687, 'feature_fraction': 0.5241133543595412, 'bagging_fraction': 0.6283444795632448, 'bagging_freq': 2, 'min_child_samples': 34, 'learning_rate': 0.007888970627774133}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:29:10,581] Trial 85 finished with value: 0.8736840501546385 and parameters: {'num_leaves': 233, 'min_data_in_leaf': 137, 'max_depth': 4, 'lambda_l1': 0.45080723354247737, 'lambda_l2': 1.0510193393166507, 'feature_fraction': 0.5027158720614198, 'bagging_fraction': 0.5748385603017075, 'bagging_freq': 2, 'min_child_samples': 29, 'learning_rate': 0.013171931121719185}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:30:37,724] Trial 86 finished with value: 0.8609655050831522 and parameters: {'num_leaves': 236, 'min_data_in_leaf': 129, 'max_depth': 4, 'lambda_l1': 0.13591305374384058, 'lambda_l2': 1.1293683974944098, 'feature_fraction': 0.5075858275394706, 'bagging_fraction': 0.5770660358867927, 'bagging_freq': 2, 'min_child_samples': 45, 'learning_rate': 0.021419045494149656}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:31:37,433] Trial 87 finished with value: 0.7324596155478509 and parameters: {'num_leaves': 236, 'min_data_in_leaf': 128, 'max_depth': 4, 'lambda_l1': 0.11297344388791936, 'lambda_l2': 3.9437148596153966, 'feature_fraction': 0.5042833367840757, 'bagging_fraction': 0.5304742319736735, 'bagging_freq': 2, 'min_child_samples': 44, 'learning_rate': 0.012761456449619697}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:33:07,361] Trial 88 finished with value: 0.8606577518342224 and parameters: {'num_leaves': 233, 'min_data_in_leaf': 108, 'max_depth': 3, 'lambda_l1': 0.06202686333296736, 'lambda_l2': 1.2563327940155231, 'feature_fraction': 0.5362134401828214, 'bagging_fraction': 0.5771401294306777, 'bagging_freq': 2, 'min_child_samples': 53, 'learning_rate': 0.005438864169255653}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:35:00,376] Trial 89 finished with value: 0.8438973880150351 and parameters: {'num_leaves': 233, 'min_data_in_leaf': 101, 'max_depth': 3, 'lambda_l1': 0.05755403401845949, 'lambda_l2': 1.0577226214164657, 'feature_fraction': 0.46433861550117206, 'bagging_fraction': 0.5704574541367113, 'bagging_freq': 2, 'min_child_samples': 55, 'learning_rate': 0.020837087171095135}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:36:08,466] Trial 90 finished with value: 0.7428405094006117 and parameters: {'num_leaves': 227, 'min_data_in_leaf': 108, 'max_depth': 5, 'lambda_l1': 0.0225423703345838, 'lambda_l2': 7.07895695906257, 'feature_fraction': 0.568404147339055, 'bagging_fraction': 0.53380709072882, 'bagging_freq': 2, 'min_child_samples': 62, 'learning_rate': 0.005963873587934928}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:37:49,039] Trial 91 finished with value: 0.844623132858427 and parameters: {'num_leaves': 246, 'min_data_in_leaf': 115, 'max_depth': 5, 'lambda_l1': 0.31746011872243207, 'lambda_l2': 1.556314456897701, 'feature_fraction': 0.5314381570813675, 'bagging_fraction': 0.6030337217692446, 'bagging_freq': 2, 'min_child_samples': 51, 'learning_rate': 0.013859658050888578}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:39:09,033] Trial 92 finished with value: 0.8515975854211147 and parameters: {'num_leaves': 214, 'min_data_in_leaf': 135, 'max_depth': 2, 'lambda_l1': 0.472545221486227, 'lambda_l2': 2.9504275933586346, 'feature_fraction': 0.520171514275054, 'bagging_fraction': 0.616471164797317, 'bagging_freq': 2, 'min_child_samples': 39, 'learning_rate': 0.024056917836940528}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:40:28,596] Trial 93 finished with value: 0.8580710139533669 and parameters: {'num_leaves': 245, 'min_data_in_leaf': 124, 'max_depth': 3, 'lambda_l1': 0.17714525657855598, 'lambda_l2': 0.8809655603707037, 'feature_fraction': 0.4782177469828297, 'bagging_fraction': 0.57683908937073, 'bagging_freq': 2, 'min_child_samples': 36, 'learning_rate': 0.009183041242640272}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:42:20,909] Trial 94 finished with value: 0.8319166127989658 and parameters: {'num_leaves': 241, 'min_data_in_leaf': 118, 'max_depth': 4, 'lambda_l1': 0.067249215586707, 'lambda_l2': 0.4594846461131971, 'feature_fraction': 0.5005321509417919, 'bagging_fraction': 0.6398325663143279, 'bagging_freq': 2, 'min_child_samples': 46, 'learning_rate': 0.020698608403546}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:44:27,815] Trial 95 finished with value: 0.8157931393225512 and parameters: {'num_leaves': 255, 'min_data_in_leaf': 90, 'max_depth': 6, 'lambda_l1': 0.028931628077588985, 'lambda_l2': 0.2845311254008775, 'feature_fraction': 0.5453658072383122, 'bagging_fraction': 0.5567976307134604, 'bagging_freq': 3, 'min_child_samples': 47, 'learning_rate': 0.005692679934237638}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:44:28,095] Trial 96 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 203, 'min_data_in_leaf': 149, 'max_depth': 4, 'lambda_l1': 0.20944770479006636, 'lambda_l2': 0.1796482610076848, 'feature_fraction': 0.5331247026734285, 'bagging_fraction': 0.5097628027678506, 'bagging_freq': 2, 'min_child_samples': 41, 'learning_rate': 0.02832765757303091}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:44:29,843] Trial 97 finished with value: 0.26100201358481145 and parameters: {'num_leaves': 181, 'min_data_in_leaf': 131, 'max_depth': 5, 'lambda_l1': 0.12200283217608247, 'lambda_l2': 1.5081869252678317, 'feature_fraction': 0.5103072067142043, 'bagging_fraction': 0.4935750011090136, 'bagging_freq': 2, 'min_child_samples': 59, 'learning_rate': 0.013536821604779349}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:45:26,550] Trial 98 finished with value: 0.47479390371771574 and parameters: {'num_leaves': 228, 'min_data_in_leaf': 108, 'max_depth': 3, 'lambda_l1': 3.456367086945408, 'lambda_l2': 0.6914628590590813, 'feature_fraction': 0.4396402155258353, 'bagging_fraction': 0.5864386665026095, 'bagging_freq': 3, 'min_child_samples': 52, 'learning_rate': 0.034132752595135214}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:46:48,554] Trial 99 finished with value: 0.8579213814507931 and parameters: {'num_leaves': 248, 'min_data_in_leaf': 137, 'max_depth': 7, 'lambda_l1': 1.003512889391328, 'lambda_l2': 9.064179713235402e-05, 'feature_fraction': 0.5562309319278164, 'bagging_fraction': 0.6597021686051743, 'bagging_freq': 2, 'min_child_samples': 31, 'learning_rate': 0.01696295760243966}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:22,562] Trial 100 finished with value: 0.8480381274498922 and parameters: {'num_leaves': 212, 'min_data_in_leaf': 126, 'max_depth': 3, 'lambda_l1': 0.005682203945511332, 'lambda_l2': 2.6013838597241423, 'feature_fraction': 0.46192090626034027, 'bagging_fraction': 0.6006185811341497, 'bagging_freq': 5, 'min_child_samples': 27, 'learning_rate': 0.02285431778748471}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:25,591] Trial 101 finished with value: 0.4706002874278234 and parameters: {'num_leaves': 238, 'min_data_in_leaf': 141, 'max_depth': 6, 'lambda_l1': 0.4032130827798604, 'lambda_l2': 0.31174104724656404, 'feature_fraction': 0.49293146330993093, 'bagging_fraction': 0.5428180028516685, 'bagging_freq': 2, 'min_child_samples': 20, 'learning_rate': 0.01037977890522243}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:27,722] Trial 102 finished with value: 0.4910775370140695 and parameters: {'num_leaves': 228, 'min_data_in_leaf': 147, 'max_depth': 5, 'lambda_l1': 0.6372732248255769, 'lambda_l2': 0.14123419623355582, 'feature_fraction': 0.480005445917533, 'bagging_fraction': 0.562815468316158, 'bagging_freq': 2, 'min_child_samples': 29, 'learning_rate': 0.16492062624324103}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:28,331] Trial 103 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 186, 'min_data_in_leaf': 139, 'max_depth': 4, 'lambda_l1': 6.663287619956902, 'lambda_l2': 4.358366984931631, 'feature_fraction': 0.4945213191931479, 'bagging_fraction': 0.6155482465339935, 'bagging_freq': 1, 'min_child_samples': 49, 'learning_rate': 0.005275754292294781}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:28,599] Trial 104 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 251, 'min_data_in_leaf': 168, 'max_depth': 3, 'lambda_l1': 0.9022459244661235, 'lambda_l2': 0.8880615314857323, 'feature_fraction': 0.5162517257467023, 'bagging_fraction': 0.5801885494687794, 'bagging_freq': 2, 'min_child_samples': 26, 'learning_rate': 0.04279931983266742}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:47,999] Trial 105 finished with value: 0.7512359644712586 and parameters: {'num_leaves': 222, 'min_data_in_leaf': 133, 'max_depth': 2, 'lambda_l1': 0.06252322456971732, 'lambda_l2': 0.42486852757456467, 'feature_fraction': 0.5374399770922252, 'bagging_fraction': 0.5171816286485466, 'bagging_freq': 1, 'min_child_samples': 42, 'learning_rate': 0.01700347184709396}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:48:51,113] Trial 106 finished with value: 0.539075683468742 and parameters: {'num_leaves': 167, 'min_data_in_leaf': 153, 'max_depth': 4, 'lambda_l1': 0.2243552175234987, 'lambda_l2': 4.718453036228927e-06, 'feature_fraction': 0.7180201051532106, 'bagging_fraction': 0.5941366243420474, 'bagging_freq': 2, 'min_child_samples': 8, 'learning_rate': 0.012705805737933099}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:50:00,164] Trial 107 finished with value: 0.8594949168478581 and parameters: {'num_leaves': 210, 'min_data_in_leaf': 119, 'max_depth': 4, 'lambda_l1': 0.4383172273787676, 'lambda_l2': 0.10657363292210743, 'feature_fraction': 0.4145450154780668, 'bagging_fraction': 0.5354265801751512, 'bagging_freq': 3, 'min_child_samples': 54, 'learning_rate': 0.030362981083781805}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:51:09,309] Trial 108 finished with value: 0.8605261296437767 and parameters: {'num_leaves': 240, 'min_data_in_leaf': 112, 'max_depth': 4, 'lambda_l1': 1.2531954596577721, 'lambda_l2': 0.13147486033119868, 'feature_fraction': 0.4129867796965466, 'bagging_fraction': 0.5360883956608118, 'bagging_freq': 3, 'min_child_samples': 55, 'learning_rate': 0.02858953244195815}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 17:52:00,386] Trial 109 finished with value: 0.8542211104927369 and parameters: {'num_leaves': 209, 'min_data_in_leaf': 120, 'max_depth': 3, 'lambda_l1': 1.3424430777955458, 'lambda_l2': 0.12259765818877692, 'feature_fraction': 0.40008363889048615, 'bagging_fraction': 0.47857753041835216, 'bagging_freq': 3, 'min_child_samples': 56, 'learning_rate': 0.03246123378434112}. Best is trial 79 with value: 0.874839158662688.
# ...
# [I 2024-05-05 17:58:49,797] Trial 114 finished with value: 0.8714906009023656 and parameters: {'num_leaves': 228, 'min_data_in_leaf': 122, 'max_depth': 4, 'lambda_l1': 0.4559967435404014, 'lambda_l2': 1.0664154496864067, 'feature_fraction': 0.43363264101717197, 'bagging_fraction': 0.5704360995188092, 'bagging_freq': 3, 'min_child_samples': 64, 'learning_rate': 0.008969825265983257}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:00:47,996] Trial 115 finished with value: 0.8082228773405243 and parameters: {'num_leaves': 219, 'min_data_in_leaf': 76, 'max_depth': 2, 'lambda_l1': 0.0396757241442035, 'lambda_l2': 1.397296222718438, 'feature_fraction': 0.41516549147620013, 'bagging_fraction': 0.5657824652687558, 'bagging_freq': 3, 'min_child_samples': 62, 'learning_rate': 0.02667506362677472}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:01:55,809] Trial 116 finished with value: 0.858624817448347 and parameters: {'num_leaves': 226, 'min_data_in_leaf': 125, 'max_depth': 4, 'lambda_l1': 0.4550194631103989, 'lambda_l2': 0.7120729050189655, 'feature_fraction': 0.4491238828623973, 'bagging_fraction': 0.5239350389240647, 'bagging_freq': 3, 'min_child_samples': 73, 'learning_rate': 0.015514739443312178}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:04:03,896] Trial 117 finished with value: 0.8312230253406725 and parameters: {'num_leaves': 230, 'min_data_in_leaf': 98, 'max_depth': 3, 'lambda_l1': 0.1969109875908387, 'lambda_l2': 1.8823689935294177, 'feature_fraction': 0.4290671767243051, 'bagging_fraction': 0.577003318586887, 'bagging_freq': 3, 'min_child_samples': 68, 'learning_rate': 0.023281443173143762}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:05:14,972] Trial 118 finished with value: 0.8591476606182489 and parameters: {'num_leaves': 205, 'min_data_in_leaf': 121, 'max_depth': 3, 'lambda_l1': 0.01419060672287683, 'lambda_l2': 0.02302615900536599, 'feature_fraction': 0.4332123146690543, 'bagging_fraction': 0.5072290044773295, 'bagging_freq': 4, 'min_child_samples': 57, 'learning_rate': 0.009321187722810122}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:06:23,823] Trial 119 finished with value: 0.8488315061844474 and parameters: {'num_leaves': 223, 'min_data_in_leaf': 110, 'max_depth': 9, 'lambda_l1': 1.811682004151708, 'lambda_l2': 0.10677899525676457, 'feature_fraction': 0.4123281049350102, 'bagging_fraction': 0.5505515314677866, 'bagging_freq': 3, 'min_child_samples': 65, 'learning_rate': 0.017881315729440565}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:07:32,135] Trial 120 finished with value: 0.8614672908790557 and parameters: {'num_leaves': 242, 'min_data_in_leaf': 131, 'max_depth': 4, 'lambda_l1': 0.08191957010328618, 'lambda_l2': 1.1607776160929337, 'feature_fraction': 0.45387066002863763, 'bagging_fraction': 0.5407924070453753, 'bagging_freq': 2, 'min_child_samples': 65, 'learning_rate': 0.029031423983997114}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:08:47,978] Trial 121 finished with value: 0.8628478819655291 and parameters: {'num_leaves': 242, 'min_data_in_leaf': 128, 'max_depth': 4, 'lambda_l1': 0.06765053552619073, 'lambda_l2': 1.064461425598508, 'feature_fraction': 0.46981278272384036, 'bagging_fraction': 0.5386680447212956, 'bagging_freq': 2, 'min_child_samples': 70, 'learning_rate': 0.0557563501116963}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:09:52,792] Trial 122 finished with value: 0.869287085463556 and parameters: {'num_leaves': 243, 'min_data_in_leaf': 132, 'max_depth': 4, 'lambda_l1': 0.08255947349384396, 'lambda_l2': 2.4301208423573923, 'feature_fraction': 0.4713305242947659, 'bagging_fraction': 0.541641372467605, 'bagging_freq': 2, 'min_child_samples': 68, 'learning_rate': 0.030652592707550348}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:10:37,535] Trial 123 finished with value: 0.8449056934351052 and parameters: {'num_leaves': 243, 'min_data_in_leaf': 132, 'max_depth': 4, 'lambda_l1': 0.020384329782624812, 'lambda_l2': 7.2334323511516745, 'feature_fraction': 0.4764518406898143, 'bagging_fraction': 0.5186755450016344, 'bagging_freq': 2, 'min_child_samples': 73, 'learning_rate': 0.04346706690614339}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:11:23,769] Trial 124 finished with value: 0.8657448760389937 and parameters: {'num_leaves': 247, 'min_data_in_leaf': 145, 'max_depth': 4, 'lambda_l1': 0.04862840977964475, 'lambda_l2': 2.4482145989093262, 'feature_fraction': 0.46494263994085977, 'bagging_fraction': 0.5701870814977663, 'bagging_freq': 2, 'min_child_samples': 80, 'learning_rate': 0.025693573218055477}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:11:26,592] Trial 125 finished with value: 0.5921248829143567 and parameters: {'num_leaves': 248, 'min_data_in_leaf': 147, 'max_depth': 4, 'lambda_l1': 0.07165261192758474, 'lambda_l2': 2.9481991691710223, 'feature_fraction': 0.45837641051940814, 'bagging_fraction': 0.5666556745167487, 'bagging_freq': 2, 'min_child_samples': 71, 'learning_rate': 0.054808332839282506}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:12:33,452] Trial 126 finished with value: 0.8560118258647671 and parameters: {'num_leaves': 234, 'min_data_in_leaf': 129, 'max_depth': 3, 'lambda_l1': 0.009316897024180117, 'lambda_l2': 4.7734479021580585, 'feature_fraction': 0.4745823996786954, 'bagging_fraction': 0.5938401157878531, 'bagging_freq': 2, 'min_child_samples': 86, 'learning_rate': 0.01355009052466735}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:12:33,754] Trial 127 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 249, 'min_data_in_leaf': 240, 'max_depth': 5, 'lambda_l1': 0.04698485091197176, 'lambda_l2': 1.0466269032959006, 'feature_fraction': 0.46676387125558116, 'bagging_fraction': 0.5742668625782557, 'bagging_freq': 2, 'min_child_samples': 76, 'learning_rate': 0.024375264942576347}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:13:35,607] Trial 128 finished with value: 0.8572783425724603 and parameters: {'num_leaves': 244, 'min_data_in_leaf': 135, 'max_depth': 3, 'lambda_l1': 0.034074468709464956, 'lambda_l2': 1.9705582701678444, 'feature_fraction': 0.4463219767040561, 'bagging_fraction': 0.5478668482550666, 'bagging_freq': 2, 'min_child_samples': 77, 'learning_rate': 0.035050893817764536}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:14:24,360] Trial 129 finished with value: 0.7457432401636555 and parameters: {'num_leaves': 216, 'min_data_in_leaf': 160, 'max_depth': 2, 'lambda_l1': 0.08269748476049278, 'lambda_l2': 9.82092268739617, 'feature_fraction': 0.4861233042892618, 'bagging_fraction': 0.6316040419477406, 'bagging_freq': 2, 'min_child_samples': 80, 'learning_rate': 0.005089522488101296}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:15:28,801] Trial 130 finished with value: 0.8559669633199045 and parameters: {'num_leaves': 231, 'min_data_in_leaf': 144, 'max_depth': 4, 'lambda_l1': 0.023613133259782065, 'lambda_l2': 4.206659158382608, 'feature_fraction': 0.5096453782113761, 'bagging_fraction': 0.5860339935089648, 'bagging_freq': 2, 'min_child_samples': 70, 'learning_rate': 0.058291157527942374}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:16:51,635] Trial 131 finished with value: 0.8588920338920338 and parameters: {'num_leaves': 241, 'min_data_in_leaf': 126, 'max_depth': 4, 'lambda_l1': 0.049929075371641055, 'lambda_l2': 1.1640842189362777, 'feature_fraction': 0.4401495076258191, 'bagging_fraction': 0.5564705691924745, 'bagging_freq': 2, 'min_child_samples': 65, 'learning_rate': 0.020906753175050762}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:18:21,992] Trial 132 finished with value: 0.8541314078078784 and parameters: {'num_leaves': 239, 'min_data_in_leaf': 115, 'max_depth': 4, 'lambda_l1': 0.15420512640205095, 'lambda_l2': 2.3882623426042606, 'feature_fraction': 0.46823437437004384, 'bagging_fraction': 0.540088322243647, 'bagging_freq': 2, 'min_child_samples': 98, 'learning_rate': 0.028021176084087995}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:18:22,329] Trial 133 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 7, 'min_data_in_leaf': 153, 'max_depth': 5, 'lambda_l1': 0.08189303760367782, 'lambda_l2': 0.4885644830162144, 'feature_fraction': 0.4275741930887059, 'bagging_fraction': 0.5119411628236485, 'bagging_freq': 2, 'min_child_samples': 68, 'learning_rate': 0.015656857408066865}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:19:14,144] Trial 134 finished with value: 0.8458899616339063 and parameters: {'num_leaves': 250, 'min_data_in_leaf': 132, 'max_depth': 3, 'lambda_l1': 4.0234162185574046e-08, 'lambda_l2': 0.920177584655846, 'feature_fraction': 0.4526472715196674, 'bagging_fraction': 0.5264553205719615, 'bagging_freq': 2, 'min_child_samples': 79, 'learning_rate': 0.009061699733620488}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:20:53,187] Trial 135 finished with value: 0.8458143164025517 and parameters: {'num_leaves': 14, 'min_data_in_leaf': 103, 'max_depth': 4, 'lambda_l1': 0.12085409595535257, 'lambda_l2': 1.4571988187721485, 'feature_fraction': 0.5026264736031129, 'bagging_fraction': 0.5002712305727043, 'bagging_freq': 2, 'min_child_samples': 64, 'learning_rate': 0.04821637172624056}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:21:31,945] Trial 136 finished with value: 0.8472176516294164 and parameters: {'num_leaves': 235, 'min_data_in_leaf': 144, 'max_depth': 5, 'lambda_l1': 0.268423020041177, 'lambda_l2': 3.367191510312311, 'feature_fraction': 0.4868683059910267, 'bagging_fraction': 0.561092910397433, 'bagging_freq': 2, 'min_child_samples': 64, 'learning_rate': 0.03205280607763155}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:23:12,049] Trial 137 finished with value: 0.8515704611292847 and parameters: {'num_leaves': 222, 'min_data_in_leaf': 122, 'max_depth': 3, 'lambda_l1': 0.0033952210770535327, 'lambda_l2': 0.6360912939511838, 'feature_fraction': 0.4626913455891828, 'bagging_fraction': 0.5741679847799872, 'bagging_freq': 2, 'min_child_samples': 71, 'learning_rate': 0.025330702582836772}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:24:51,177] Trial 138 finished with value: 0.859676652323711 and parameters: {'num_leaves': 244, 'min_data_in_leaf': 111, 'max_depth': 4, 'lambda_l1': 0.2148475831913429, 'lambda_l2': 1.6102837982142184, 'feature_fraction': 0.43671342965545573, 'bagging_fraction': 0.6032721964342432, 'bagging_freq': 2, 'min_child_samples': 95, 'learning_rate': 0.042453896921570804}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:28:20,595] Trial 139 finished with value: 0.70338572103278 and parameters: {'num_leaves': 252, 'min_data_in_leaf': 17, 'max_depth': 3, 'lambda_l1': 0.05142488638296922, 'lambda_l2': 2.321319988918651, 'feature_fraction': 0.7663903920298475, 'bagging_fraction': 0.6193181215582577, 'bagging_freq': 2, 'min_child_samples': 60, 'learning_rate': 0.019953898794974473}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:28:20,888] Trial 140 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 230, 'min_data_in_leaf': 137, 'max_depth': 4, 'lambda_l1': 0.12205114973140095, 'lambda_l2': 0.3841660651149326, 'feature_fraction': 0.49898136514909064, 'bagging_fraction': 0.4903627470288878, 'bagging_freq': 2, 'min_child_samples': 83, 'learning_rate': 0.011997570846520722}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:30:00,911] Trial 141 finished with value: 0.8456643030172442 and parameters: {'num_leaves': 245, 'min_data_in_leaf': 111, 'max_depth': 4, 'lambda_l1': 0.20401713293153667, 'lambda_l2': 1.3910256764815538, 'feature_fraction': 0.43288008232345626, 'bagging_fraction': 0.6024574657264599, 'bagging_freq': 5, 'min_child_samples': 92, 'learning_rate': 0.037349933481204876}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:31:24,546] Trial 142 finished with value: 0.8588162382280028 and parameters: {'num_leaves': 238, 'min_data_in_leaf': 126, 'max_depth': 5, 'lambda_l1': 0.32561955086260874, 'lambda_l2': 6.1393417337179566, 'feature_fraction': 0.4496508765627458, 'bagging_fraction': 0.5954971080929127, 'bagging_freq': 2, 'min_child_samples': 96, 'learning_rate': 0.0406683649756686}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:33:16,713] Trial 143 finished with value: 0.8420219758455053 and parameters: {'num_leaves': 244, 'min_data_in_leaf': 107, 'max_depth': 4, 'lambda_l1': 0.029895612382653543, 'lambda_l2': 0.9773610185500486, 'feature_fraction': 0.4231413191060446, 'bagging_fraction': 0.5838033035225858, 'bagging_freq': 2, 'min_child_samples': 87, 'learning_rate': 0.04352344896605674}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:34:49,329] Trial 144 finished with value: 0.8429350605821193 and parameters: {'num_leaves': 256, 'min_data_in_leaf': 115, 'max_depth': 6, 'lambda_l1': 0.0844100411302947, 'lambda_l2': 2.2245404407173095, 'feature_fraction': 0.4027311739256344, 'bagging_fraction': 0.542660400426271, 'bagging_freq': 6, 'min_child_samples': 67, 'learning_rate': 0.029900018044156113}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:35:53,629] Trial 145 finished with value: 0.8596525478878421 and parameters: {'num_leaves': 3, 'min_data_in_leaf': 130, 'max_depth': 3, 'lambda_l1': 1.0290263792508691, 'lambda_l2': 0.6361878259118406, 'feature_fraction': 0.4787964166536852, 'bagging_fraction': 0.5641106413834904, 'bagging_freq': 2, 'min_child_samples': 100, 'learning_rate': 0.04986243751073818}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:35:53,925] Trial 146 finished with value: 0.00019036740909956218 and parameters: {'num_leaves': 233, 'min_data_in_leaf': 150, 'max_depth': 4, 'lambda_l1': 0.5862383046979907, 'lambda_l2': 3.5223375252273965, 'feature_fraction': 0.4573777385713371, 'bagging_fraction': 0.5322536664972086, 'bagging_freq': 2, 'min_child_samples': 74, 'learning_rate': 0.017022013409724097}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:37:08,040] Trial 147 finished with value: 0.8447203667791904 and parameters: {'num_leaves': 239, 'min_data_in_leaf': 141, 'max_depth': 5, 'lambda_l1': 0.17485945218803922, 'lambda_l2': 0.27214562701936496, 'feature_fraction': 0.5145166176026535, 'bagging_fraction': 0.6105213945730408, 'bagging_freq': 2, 'min_child_samples': 69, 'learning_rate': 0.035109509296542364}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:38:02,923] Trial 148 finished with value: 0.8219662146132733 and parameters: {'num_leaves': 225, 'min_data_in_leaf': 121, 'max_depth': 4, 'lambda_l1': 0.2390270224627369, 'lambda_l2': 0.8419532873601111, 'feature_fraction': 0.4425694314294373, 'bagging_fraction': 0.5520717936445734, 'bagging_freq': 2, 'min_child_samples': 33, 'learning_rate': 0.1989758259738088}. Best is trial 79 with value: 0.874839158662688.
# [I 2024-05-05 18:39:30,107] Trial 149 finished with value: 0.8554049436402377 and parameters: {'num_leaves': 247, 'min_data_in_leaf': 135, 'max_depth': 3, 'lambda_l1': 0.018948650476499275, 'lambda_l2': 1.2850273035984732, 'feature_fraction': 0.5241245327972238, 'bagging_fraction': 0.585442106264705, 'bagging_freq': 2, 'min_child_samples': 61, 'learning_rate': 0.056201033518674684}. Best is trial 79 with value: 0.874839158662688.

# %%
best_params[0][1]
# Out:
# {'num_leaves': 9,
#  'min_data_in_leaf': 151,
#  'max_depth': 3,
#  'lambda_l1': 0.05156122427614393,
#  'lambda_l2': 0.917067067731611,
#  'feature_fraction': 0.5345089078095386,
#  'bagging_fraction': 0.6022498606851232,
#  'bagging_freq': 2,
#  'min_child_samples': 30,
#  'learning_rate': 0.011302934154635014}

# %%
best_params[0][1].update({'objective': 'multiclass',
'metric': 'multi_logloss',
'verbosity': -1,
'boosting_type': 'gbdt',
'n_estimators': 1_000,
'early_stopping_round': 10,
'device': 'gpu'})

# %%
[I 2024-05-05 17:21:25,727] Trial 79 finished with value: 0.874839158662688 and parameters: {'num_leaves': 9, 'min_data_in_leaf': 151, 'max_depth': 3, 'lambda_l1': 0.05156122427614393, 'lambda_l2': 0.917067067731611, 'feature_fraction': 0.5345089078095386, 'bagging_fraction': 0.6022498606851232, 'bagging_freq': 2, 'min_child_samples': 30, 'learning_rate': 0.011302934154635014}. Best is trial 79 with value: 0.874839158662688.

# %%
best_params[0][1]
# Out:
# {'num_leaves': 9,
#  'min_data_in_leaf': 151,
#  'max_depth': 3,
#  'lambda_l1': 0.05156122427614393,
#  'lambda_l2': 0.917067067731611,
#  'feature_fraction': 0.5345089078095386,
#  'bagging_fraction': 0.6022498606851232,
#  'bagging_freq': 2,
#  'min_child_samples': 30,
#  'learning_rate': 0.011302934154635014,
#  'objective': 'multiclass',
#  'metric': 'multi_logloss',
#  'verbosity': -1,
#  'boosting_type': 'gbdt',
#  'n_estimators': 1000,
#  'device': 'gpu'}

# %%
import mlflow
from sklearn.preprocessing import StandardScaler

from sklearn import metrics

mlflow.set_tracking_uri("http://127.0.0.1:5000")
experiment = mlflow.set_experiment(f"{len(set(y))} classes, 5 per class")

run_name = "lightgbm normalized optuna"

with mlflow.start_run(run_name=run_name) as run:
    model_params = best_params[0][1]
    model_lgb = lgb.LGBMClassifier(**model_params)
    
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model_lgb.fit(X_train_scaled, y_train)
    predicts = model_lgb.predict(X_test_scaled)

    mlflow.log_metric("train f1_weighted", metrics.f1_score(y_train, model_lgb.predict(X_train_scaled), average="weighted"))
    mlflow.log_metric("f1_weighted", metrics.f1_score(y_test, predicts, average="weighted"))
    mlflow.log_metric("f1_micro", metrics.f1_score(y_test, predicts, average="micro"))
    mlflow.log_metric("accuracy", metrics.accuracy_score(y_test, predicts))
    
    mlflow.log_params(model_params)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 19
#      16 X_train_scaled = scaler.fit_transform(X_train)
#      17 X_test_scaled = scaler.transform(X_test)
# ---> 19 model_lgb.fit(X_train_scaled, y_train)
#      20 predicts = model_lgb.predict(X_test_scaled)
#      22 mlflow.log_metric("train f1_weighted", metrics.f1_score(y_train, model_lgb.predict(X_train_scaled), average="weighted"))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\lightgbm\sklearn.py:1187, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1184         else:
#    1185             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1187 super().fit(
#    1188     X,
#    1189     _y,
#    1190     sample_weight=sample_weight,
#    1191     init_score=init_score,
#    1192     eval_set=valid_sets,
#    1193     eval_names=eval_names,
#    1194     eval_sample_weight=eval_sample_weight,
#    1195     eval_class_weight=eval_class_weight,
#    1196     eval_init_score=eval_init_score,
#    1197     eval_metric=eval_metric,
#    1198     feature_name=feature_name,
#    1199     categorical_feature=categorical_feature,
#    1200     callbacks=callbacks,
#    1201     init_model=init_model
#    1202 )
#    1203 return self
#
# File ~\AppData\Roaming\Python\Python39\site-packages\lightgbm\sklearn.py:885, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     882 evals_result: _EvalResultDict = {}
#     883 callbacks.append(record_evaluation(evals_result))
# --> 885 self._Booster = train(
#     886     params=params,
#     887     train_set=train_set,
#     888     num_boost_round=self.n_estimators,
#     889     valid_sets=valid_sets,
#     890     valid_names=eval_names,
#     891     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     892     init_model=init_model,
#     893     feature_name=feature_name,
#     894     callbacks=callbacks
#     895 )
#     897 self._evals_result = evals_result
#     898 self._best_iteration = self._Booster.best_iteration
#
# File ~\AppData\Roaming\Python\Python39\site-packages\lightgbm\engine.py:276, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     268 for cb in callbacks_before_iter:
#     269     cb(callback.CallbackEnv(model=booster,
#     270                             params=params,
#     271                             iteration=i,
#     272                             begin_iteration=init_iteration,
#     273                             end_iteration=init_iteration + num_boost_round,
#     274                             evaluation_result_list=None))
# --> 276 booster.update(fobj=fobj)
#     278 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     279 # check evaluation result.
#
# File ~\AppData\Roaming\Python\Python39\site-packages\lightgbm\basic.py:3891, in Booster.update(self, train_set, fobj)
#    3889 if self.__set_objective_to_none:
#    3890     raise LightGBMError('Cannot update due to null objective function.')
# -> 3891 _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3892     self._handle,
#    3893     ctypes.byref(is_finished)))
#    3894 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    3895 return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
model_params = {
        "task_type": 'GPU',
        "devices": '0',
        "iterations": 1_000,
        'depth': 4,
        'random_strength': 5,
        "bagging_temperature": 1,
    }
model_cb = catboost.CatBoostClassifier(verbose=10, **model_params)
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
# X_train_scaled = X_train
# X_test_scaled = X_test

model_cb.fit(X_train, y_train)
predicts = model_cb.predict(X_test)

print(metrics.f1_score(y_train, model_cb.predict(X_train), average="weighted"))
print()
print(metrics.f1_score(y_test, predicts, average="weighted"))
print(metrics.f1_score(y_test, predicts, average="micro"))
print(metrics.accuracy_score(y_test, predicts))
# Out:
# Learning rate set to 0.072924
# 0:	learn: 5.8692962	total: 72.6ms	remaining: 1m 12s
# 10:	learn: 5.8365444	total: 853ms	remaining: 1m 16s
# 20:	learn: 5.8084691	total: 1.54s	remaining: 1m 11s
# 30:	learn: 5.7859927	total: 2.2s	remaining: 1m 8s
# 40:	learn: 5.7748466	total: 2.88s	remaining: 1m 7s
# 50:	learn: 5.7369582	total: 3.65s	remaining: 1m 7s
# 60:	learn: 5.6514974	total: 4.5s	remaining: 1m 9s
# 70:	learn: 5.5763082	total: 5.36s	remaining: 1m 10s
# 80:	learn: 5.4816086	total: 6.95s	remaining: 1m 18s
# 90:	learn: 5.4751683	total: 8.6s	remaining: 1m 25s
# 100:	learn: 5.3675075	total: 10.9s	remaining: 1m 37s
# 110:	learn: 5.2386366	total: 13.3s	remaining: 1m 46s
# 120:	learn: 4.9981324	total: 16.5s	remaining: 2m
# 130:	learn: 4.7477517	total: 20.4s	remaining: 2m 15s
# 140:	learn: 4.4939867	total: 24s	remaining: 2m 26s
# 150:	learn: 4.2778867	total: 28.1s	remaining: 2m 38s
# 160:	learn: 4.0535405	total: 31.9s	remaining: 2m 46s
# 170:	learn: 3.8146369	total: 35.7s	remaining: 2m 53s
# 180:	learn: 3.6300332	total: 39.3s	remaining: 2m 57s
# 190:	learn: 3.4314039	total: 43s	remaining: 3m 2s
# 200:	learn: 3.2509363	total: 46.8s	remaining: 3m 6s
# 210:	learn: 3.0658476	total: 50.6s	remaining: 3m 9s
# 220:	learn: 2.8753399	total: 54.5s	remaining: 3m 12s
# 230:	learn: 2.7065391	total: 58.2s	remaining: 3m 13s
# 240:	learn: 2.5498461	total: 1m 1s	remaining: 3m 14s
# 250:	learn: 2.4107673	total: 1m 5s	remaining: 3m 15s
# 260:	learn: 2.2519984	total: 1m 9s	remaining: 3m 15s
# 270:	learn: 2.1184681	total: 1m 12s	remaining: 3m 15s
# 280:	learn: 2.0020386	total: 1m 16s	remaining: 3m 15s
# 290:	learn: 1.8705491	total: 1m 20s	remaining: 3m 16s
# 300:	learn: 1.7551028	total: 1m 24s	remaining: 3m 16s
# 310:	learn: 1.6556434	total: 1m 28s	remaining: 3m 16s
# 320:	learn: 1.5614285	total: 1m 32s	remaining: 3m 14s
# 330:	learn: 1.4695845	total: 1m 35s	remaining: 3m 13s
# 340:	learn: 1.3715801	total: 1m 39s	remaining: 3m 12s
# 350:	learn: 1.2899847	total: 1m 42s	remaining: 3m 10s
# 360:	learn: 1.2095194	total: 1m 46s	remaining: 3m 8s
# 370:	learn: 1.1430312	total: 1m 49s	remaining: 3m 6s
# 380:	learn: 1.0775075	total: 1m 53s	remaining: 3m 4s
# 390:	learn: 1.0118761	total: 1m 57s	remaining: 3m 3s
# 400:	learn: 0.9592927	total: 2m 1s	remaining: 3m
# 410:	learn: 0.9015621	total: 2m 4s	remaining: 2m 58s
# 420:	learn: 0.8574025	total: 2m 8s	remaining: 2m 56s
# 430:	learn: 0.8138891	total: 2m 12s	remaining: 2m 54s
# 440:	learn: 0.7731361	total: 2m 15s	remaining: 2m 52s
# 450:	learn: 0.7321444	total: 2m 19s	remaining: 2m 49s
# 460:	learn: 0.6976940	total: 2m 23s	remaining: 2m 47s
# 470:	learn: 0.6685185	total: 2m 26s	remaining: 2m 44s
# 480:	learn: 0.6368186	total: 2m 29s	remaining: 2m 41s
# 490:	learn: 0.6083378	total: 2m 33s	remaining: 2m 38s
# 500:	learn: 0.5824977	total: 2m 36s	remaining: 2m 35s
# 510:	learn: 0.5542845	total: 2m 39s	remaining: 2m 33s
# 520:	learn: 0.5279878	total: 2m 43s	remaining: 2m 30s
# 530:	learn: 0.5064827	total: 2m 47s	remaining: 2m 28s
# 540:	learn: 0.4897171	total: 2m 51s	remaining: 2m 25s
# 550:	learn: 0.4681275	total: 2m 54s	remaining: 2m 22s
# 560:	learn: 0.4485626	total: 2m 57s	remaining: 2m 19s
# 570:	learn: 0.4302407	total: 3m 1s	remaining: 2m 16s
# 580:	learn: 0.4124566	total: 3m 4s	remaining: 2m 13s
# 590:	learn: 0.3964954	total: 3m 8s	remaining: 2m 10s
# 600:	learn: 0.3811039	total: 3m 11s	remaining: 2m 7s
# 610:	learn: 0.3676037	total: 3m 14s	remaining: 2m 4s
# 620:	learn: 0.3538136	total: 3m 18s	remaining: 2m 1s
# 630:	learn: 0.3414390	total: 3m 22s	remaining: 1m 58s
# 640:	learn: 0.3303406	total: 3m 26s	remaining: 1m 55s
# 650:	learn: 0.3207676	total: 3m 30s	remaining: 1m 52s
# 660:	learn: 0.3103265	total: 3m 34s	remaining: 1m 49s
# 670:	learn: 0.3006808	total: 3m 37s	remaining: 1m 46s
# 680:	learn: 0.2901129	total: 3m 41s	remaining: 1m 43s
# 690:	learn: 0.2814560	total: 3m 44s	remaining: 1m 40s
# 700:	learn: 0.2731731	total: 3m 49s	remaining: 1m 37s
# 710:	learn: 0.2649902	total: 3m 52s	remaining: 1m 34s
# 720:	learn: 0.2581552	total: 3m 56s	remaining: 1m 31s
# 730:	learn: 0.2494228	total: 4m	remaining: 1m 28s
# 740:	learn: 0.2426212	total: 4m 4s	remaining: 1m 25s
# 750:	learn: 0.2351377	total: 4m 8s	remaining: 1m 22s
# 760:	learn: 0.2290775	total: 4m 12s	remaining: 1m 19s
# 770:	learn: 0.2229813	total: 4m 15s	remaining: 1m 16s
# 780:	learn: 0.2178340	total: 4m 21s	remaining: 1m 13s
# 790:	learn: 0.2127245	total: 4m 26s	remaining: 1m 10s
# 800:	learn: 0.2076646	total: 4m 31s	remaining: 1m 7s
# 810:	learn: 0.2035256	total: 4m 35s	remaining: 1m 4s
# 820:	learn: 0.1983936	total: 4m 39s	remaining: 1m
# 830:	learn: 0.1937599	total: 4m 43s	remaining: 57.6s
# 840:	learn: 0.1892132	total: 4m 46s	remaining: 54.2s
# 850:	learn: 0.1849654	total: 4m 50s	remaining: 50.8s
# 860:	learn: 0.1808177	total: 4m 53s	remaining: 47.4s
# 870:	learn: 0.1768094	total: 4m 57s	remaining: 44s
# 880:	learn: 0.1729374	total: 5m	remaining: 40.6s
# 890:	learn: 0.1693802	total: 5m 4s	remaining: 37.3s
# 900:	learn: 0.1654486	total: 5m 8s	remaining: 33.9s
# 910:	learn: 0.1625323	total: 5m 11s	remaining: 30.5s
# 920:	learn: 0.1591294	total: 5m 15s	remaining: 27s
# 930:	learn: 0.1560428	total: 5m 18s	remaining: 23.6s
# 940:	learn: 0.1531731	total: 5m 22s	remaining: 20.2s
# 950:	learn: 0.1502718	total: 5m 26s	remaining: 16.8s
# 960:	learn: 0.1475408	total: 5m 30s	remaining: 13.4s
# 970:	learn: 0.1446313	total: 5m 33s	remaining: 9.97s
# 980:	learn: 0.1418886	total: 5m 37s	remaining: 6.53s
# 990:	learn: 0.1392986	total: 5m 40s	remaining: 3.09s
# 999:	learn: 0.1368237	total: 5m 43s	remaining: 0us
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 19
#      16 model_cb.fit(X_train, y_train)
#      17 predicts = model_cb.predict(X_test)
# ---> 19 print(metrics.f1_score(y_train, model_cb.predict(X_train), average="weighted"))
#      20 print()
#      21 print(metrics.f1_score(y_test, predicts, average="weighted"))
#
# NameError: name 'metrics' is not defined

# %%
print(metrics.f1_score(y_train, model_cb.predict(X_train), average="weighted"))
print()
print(metrics.f1_score(y_test, predicts, average="weighted"))
print(metrics.f1_score(y_test, predicts, average="micro"))
print(metrics.accuracy_score(y_test, predicts))
# Out:
# 0.9994293214632197
#
# 0.7445141173954732
# 0.7536723163841808
# 0.7536723163841808

# %%
import mlflow
from sklearn.preprocessing import StandardScaler

from sklearn import metrics

mlflow.set_tracking_uri("http://127.0.0.1:5000")
experiment = mlflow.set_experiment(f"{len(set(y))} classes, 5 per class")

run_name = "catboost tuned"

with mlflow.start_run(run_name=run_name) as run:
    model_params = {
        "task_type": 'GPU',
        "devices": '0',
        "iterations": 1_000,
        'depth': 4,
        'random_strength': 5,
        "bagging_temperature": 1,
    }
    model_cb = catboost.CatBoostClassifier(verbose=10, **model_params)
    
    # scaler = StandardScaler()
    # X_train_scaled = scaler.fit_transform(X_train)
    # X_test_scaled = scaler.transform(X_test)
    X_train_scaled = X_train
    X_test_scaled = X_test

    model_cb.fit(X_train_scaled, y_train)
    predicts = model_cb.predict(X_test_scaled)

    mlflow.log_metric("train f1_weighted", metrics.f1_score(y_train, model_cb.predict(X_train_scaled), average="weighted"))
    mlflow.log_metric("f1_weighted", metrics.f1_score(y_test, predicts, average="weighted"))
    mlflow.log_metric("f1_micro", metrics.f1_score(y_test, predicts, average="micro"))
    mlflow.log_metric("accuracy", metrics.accuracy_score(y_test, predicts))
    
    mlflow.log_params(model_params)

    mlflow.catboost.log_model(model_cb, artifact_path=f"mlflow/{run_name}/model")
# Out:
# Learning rate set to 0.072924
# 0:	learn: 5.8155174	total: 811ms	remaining: 13m 30s
# 10:	learn: 5.7896010	total: 3.43s	remaining: 5m 8s
# 20:	learn: 5.7608713	total: 5.78s	remaining: 4m 29s
# 30:	learn: 5.7281002	total: 8.2s	remaining: 4m 16s
# 40:	learn: 5.6589595	total: 11s	remaining: 4m 16s
# 50:	learn: 5.5896926	total: 14.2s	remaining: 4m 24s
# 60:	learn: 5.5491079	total: 16.8s	remaining: 4m 18s
# 70:	learn: 5.5451503	total: 18.8s	remaining: 4m 5s
# 80:	learn: 5.5062980	total: 21.2s	remaining: 4m
# 90:	learn: 5.4662236	total: 23.7s	remaining: 3m 56s
# 100:	learn: 5.3617320	total: 27.2s	remaining: 4m 1s
# 110:	learn: 5.1641442	total: 31.4s	remaining: 4m 11s
# 120:	learn: 4.8283512	total: 38.1s	remaining: 4m 36s
# 130:	learn: 4.4873061	total: 44.8s	remaining: 4m 57s
# 140:	learn: 4.2118341	total: 51.4s	remaining: 5m 13s
# 150:	learn: 3.9836346	total: 58.1s	remaining: 5m 26s
# 160:	learn: 3.7377839	total: 1m 4s	remaining: 5m 38s
# 170:	learn: 3.5278287	total: 1m 11s	remaining: 5m 47s
# 180:	learn: 3.3421743	total: 1m 18s	remaining: 5m 56s
# 190:	learn: 3.1406261	total: 1m 25s	remaining: 6m 2s
# 200:	learn: 2.9501879	total: 1m 32s	remaining: 6m 6s
# 210:	learn: 2.7631839	total: 1m 39s	remaining: 6m 10s
# 220:	learn: 2.6061264	total: 1m 45s	remaining: 6m 12s
# 230:	learn: 2.4298988	total: 1m 52s	remaining: 6m 14s
# 240:	learn: 2.2804483	total: 1m 59s	remaining: 6m 15s
# 250:	learn: 2.1239379	total: 2m 5s	remaining: 6m 15s
# 260:	learn: 1.9943977	total: 2m 12s	remaining: 6m 15s
# 270:	learn: 1.8868735	total: 2m 19s	remaining: 6m 14s
# 280:	learn: 1.7597048	total: 2m 25s	remaining: 6m 13s
# 290:	learn: 1.6243165	total: 2m 32s	remaining: 6m 11s
# 300:	learn: 1.5068826	total: 2m 39s	remaining: 6m 10s
# 310:	learn: 1.4032489	total: 2m 46s	remaining: 6m 8s
# 320:	learn: 1.3179672	total: 2m 53s	remaining: 6m 6s
# 330:	learn: 1.2384015	total: 2m 59s	remaining: 6m 3s
# 340:	learn: 1.1626441	total: 3m 6s	remaining: 6m
# 350:	learn: 1.0886613	total: 3m 13s	remaining: 5m 56s
# 360:	learn: 1.0272915	total: 3m 19s	remaining: 5m 53s
# 370:	learn: 0.9572918	total: 3m 26s	remaining: 5m 49s
# 380:	learn: 0.9017877	total: 3m 33s	remaining: 5m 46s
# 390:	learn: 0.8611616	total: 3m 39s	remaining: 5m 41s
# 400:	learn: 0.8113960	total: 3m 46s	remaining: 5m 37s
# 410:	learn: 0.7699392	total: 3m 52s	remaining: 5m 33s
# 420:	learn: 0.7298906	total: 3m 59s	remaining: 5m 28s
# 430:	learn: 0.6972147	total: 4m 5s	remaining: 5m 24s
# 440:	learn: 0.6709344	total: 4m 12s	remaining: 5m 19s
# 450:	learn: 0.6406432	total: 4m 18s	remaining: 5m 15s
# 460:	learn: 0.6131330	total: 4m 25s	remaining: 5m 10s
# 470:	learn: 0.5823898	total: 4m 31s	remaining: 5m 5s
# 480:	learn: 0.5520898	total: 4m 38s	remaining: 5m
# 490:	learn: 0.5254032	total: 4m 45s	remaining: 4m 55s
# 500:	learn: 0.5034775	total: 4m 51s	remaining: 4m 50s
# 510:	learn: 0.4832307	total: 4m 58s	remaining: 4m 45s
# 520:	learn: 0.4643942	total: 5m 4s	remaining: 4m 39s
# 530:	learn: 0.4449703	total: 5m 10s	remaining: 4m 34s
# 540:	learn: 0.4278383	total: 5m 17s	remaining: 4m 29s
# 550:	learn: 0.4131748	total: 5m 24s	remaining: 4m 24s
# 560:	learn: 0.4021555	total: 5m 30s	remaining: 4m 18s
# 570:	learn: 0.3851925	total: 5m 37s	remaining: 4m 13s
# 580:	learn: 0.3703247	total: 5m 44s	remaining: 4m 8s
# 590:	learn: 0.3576141	total: 5m 50s	remaining: 4m 2s
# 600:	learn: 0.3455350	total: 5m 57s	remaining: 3m 57s
# 610:	learn: 0.3379608	total: 6m 4s	remaining: 3m 52s
# 620:	learn: 0.3292639	total: 6m 10s	remaining: 3m 46s
# 630:	learn: 0.3188621	total: 6m 17s	remaining: 3m 40s
# 640:	learn: 0.3094260	total: 6m 24s	remaining: 3m 35s
# 650:	learn: 0.2998970	total: 6m 30s	remaining: 3m 29s
# 660:	learn: 0.2904659	total: 6m 37s	remaining: 3m 23s
# 670:	learn: 0.2825895	total: 6m 43s	remaining: 3m 17s
# 680:	learn: 0.2733776	total: 6m 50s	remaining: 3m 12s
# 690:	learn: 0.2663000	total: 6m 56s	remaining: 3m 6s
# 700:	learn: 0.2587870	total: 7m 2s	remaining: 3m
# 710:	learn: 0.2512042	total: 7m 9s	remaining: 2m 54s
# 720:	learn: 0.2440067	total: 7m 15s	remaining: 2m 48s
# 730:	learn: 0.2371790	total: 7m 22s	remaining: 2m 42s
# 740:	learn: 0.2309840	total: 7m 28s	remaining: 2m 36s
# 750:	learn: 0.2249937	total: 7m 35s	remaining: 2m 30s
# 760:	learn: 0.2195056	total: 7m 41s	remaining: 2m 24s
# 770:	learn: 0.2139666	total: 7m 47s	remaining: 2m 18s
# 780:	learn: 0.2083643	total: 7m 54s	remaining: 2m 12s
# 790:	learn: 0.2042226	total: 8m	remaining: 2m 7s
# 800:	learn: 0.2004141	total: 8m 6s	remaining: 2m
# 810:	learn: 0.1956618	total: 8m 13s	remaining: 1m 54s
# 820:	learn: 0.1911399	total: 8m 19s	remaining: 1m 48s
# 830:	learn: 0.1868991	total: 8m 25s	remaining: 1m 42s
# 840:	learn: 0.1823534	total: 8m 32s	remaining: 1m 36s
# 850:	learn: 0.1787295	total: 8m 38s	remaining: 1m 30s
# 860:	learn: 0.1752953	total: 8m 45s	remaining: 1m 24s
# 870:	learn: 0.1716993	total: 8m 51s	remaining: 1m 18s
# 880:	learn: 0.1685720	total: 8m 57s	remaining: 1m 12s
# 890:	learn: 0.1647903	total: 9m 4s	remaining: 1m 6s
# 900:	learn: 0.1606669	total: 9m 10s	remaining: 1m
# 910:	learn: 0.1582230	total: 9m 16s	remaining: 54.4s
# 920:	learn: 0.1550678	total: 9m 22s	remaining: 48.3s
# 930:	learn: 0.1519328	total: 9m 29s	remaining: 42.2s
# 940:	learn: 0.1494763	total: 9m 35s	remaining: 36.1s
# 950:	learn: 0.1469724	total: 9m 41s	remaining: 30s
# 960:	learn: 0.1443821	total: 9m 47s	remaining: 23.9s
# 970:	learn: 0.1416100	total: 9m 54s	remaining: 17.7s
# 980:	learn: 0.1387448	total: 10m	remaining: 11.6s
# 990:	learn: 0.1364854	total: 10m 6s	remaining: 5.51s
# 999:	learn: 0.1343228	total: 10m 12s	remaining: 0us

# %%
model_params = {
        "task_type": 'GPU',
        "devices": '0',
        "iterations": 1_000,
        'depth': 4,
        'random_strength': 5,
    }
